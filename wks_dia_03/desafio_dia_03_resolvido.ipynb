# %% [markdown]
# # 🎯 Desafio dia 03
#
# ## 💻 Análise de Dados com Python

# %%
# Importar bibliotecas e atribuir 'apelido' a elas: pd e plt
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Carregar dados
df = pd.read_csv('/content/dados.csv')

# %% [markdown]
# ### ▶ Tabela 0:
#
# ---

# %%
# Imprimir dados
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### ▶ Tabela 1:
#
# ---

# %%
# Valores mínimos, máximos e médios de pontuação de cada matéria
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Da tabela 1, pode-se afirmar que as disciplinas de matemática, leitura e escrita possuem os seguintes valores mínimo, máximo e médio (apresentados abaixo com 2 casas decimais e com arredondamento, para melhor visualização das notas):
#
# Valor|Nota de Matemática | Nota de Leitura | Nota de Escrita
# -----|:-----------:|:---------:|:--------:
# Mínimo| 00,00 | 17,00 | 10,00
# Máximo| 100,00 | 100,00 | 100,00
# Médio| 66,09 | 69,17 | 68,05

# %%
# Agrupar alunos por raça/etnia
df2 = df.groupby('race/ethnicity')[['math score']].count()

# %% [markdown]
# ### ▶ Tabela 2:
#
# ---

# %%
# Quantidade de alunos por raça/etnia - grupo
df2
# Out:
#                 math score
# race/ethnicity
# group A                 89
# group B                190
# group C                319
# group D                262
# group E                140

# %% [markdown]
# A Tabela 2 acima mostra a quantidade de alunos por raça/etnia - grupo. Pode-se inferir que existem mais alunos da etnia _grupo C_ (319) e menos alunos da etnia _grupo A_ (89).

# %%
# nota média em Matemática
df3 = df.groupby('race/ethnicity')[['math score']].mean()

# %% [markdown]
# ### ▶ Tabela 3:
#
# ---

# %%
# nota média em Matemática
df3
# Out:
#                 math score
# race/ethnicity
# group A          61.629213
# group B          63.452632
# group C          64.463950
# group D          67.362595
# group E          73.821429

# %% [markdown]
# Já a Tabela 3 acima apresenta a média em Matemática por etnia/raça - grupo. Assim, a etnia _grupo E_ obteve a melhor média, sendo de 73,82.

# %% [markdown]
# ### 📊 Gráfico 1:
#
# ---

# %%
# Plotar um gráfico com a nota média em Matemática para cada grupo disponível
df3.plot(kind = 'bar').set_title('Nota média em Matemática por raça/etnia (grupo)')
# Out:
# Text(0.5, 1.0, 'Nota média em Matemática por raça/etnia (grupo)')

# %% [markdown]
# O Gráfico 1 mostra a nota média em Matemática por raça/etnia (grupo). O eixo y representa a nota média em matemática e o eixo x representa a raça/etnia. A etnia _grupo E_ obteve a melhor média e a etnia _grupo A_ apresentou a média mais baixa.

# %%
# Agrupar alunos por nível de escolaridade dos pais
df4 = df.groupby('parental level of education')[['writing score']].count()

# %% [markdown]
# ### ▶ Tabela 4:
#
# ---

# %%
# Quantidade de alunos que tem pais em determinado Nível de Escolaridade
df4
# Out:
#                              writing score
# parental level of education
# associate's degree                     222
# bachelor's degree                      118
# high school                            196
# master's degree                         59
# some college                           226
# some high school                       179

# %% [markdown]
# A Tabela 4 acima mostra a quantidade de alunos que tem pais em determinado nível de escolaridade. Pode-se inferir, por exemplo, que existem 226 alunos com pais que possuem graduação incompleta e apenas 59 alunos têm pais que possuem mestrado.

# %%
# Plotar um gráfico com a nota média em Escrita para cada Nível de Escolaridade dos Pais
df5 = df.groupby('parental level of education')[['writing score']].mean()

# %% [markdown]
# ### ▶ Tabela 5:
#
# ---

# %%
# nota média em escrita
df5
# Out:
#                              writing score
# parental level of education
# associate's degree               69.896396
# bachelor's degree                73.381356
# high school                      62.448980
# master's degree                  75.677966
# some college                     68.840708
# some high school                 64.888268

# %% [markdown]
# Já a Tabela 5 acima mostra a média das notas dos alunos em escrita, relacionando com o nível de escolaridade dos pais. A tendência é que quanto maior o nível de escolaridade dos pais, maiores são as médias em escrita dos alunos.
#
# OBS: Segue abaixo tabela com tradução para facilitar o entendimento.
#
# parental level of education | tradução
# :-------------|:-------------
# associate's degree | técnico
# bachelor's degree | graduação
# high school | ensino médio
# master's degree | mestrado
# some college | ensino superior incompleto
# some high school | ensino medio incompleto

# %% [markdown]
# ### 📊 Gráfico 2:
#
# ---

# %%
df5.plot(kind = 'bar').set_title('Nota média em Escrita por Nível de Escolaridade dos Pais')
# Out:
# Text(0.5, 1.0, 'Nota média em Escrita por Nível de Escolaridade dos Pais')

# %% [markdown]
# O Gráfico 2 mostra a nota média em Escrita por nível de escolaridade dos pais. O eixo y representa a nota média em escrita e o eixo x representa o nível de nscolaridade dos pais. Os alunos que possuem pais com mestrado possuem melhores médias em Escrita, seguidos dos alunos que possuem pais graduados.

# %%
# Agrupar alunos por participação em um curso preparatório para os testes
df6 = df.groupby('test preparation course')[['reading score']].count()

# %% [markdown]
# ### ▶ Tabela 6:
#
# ---

# %%
# Quantidade de alunos que concluíram ou não o curso preparatório para os testes
df6
# Out:
#                          reading score
# test preparation course
# completed                          358
# none                               642

# %% [markdown]
# A Tabela 6 acima mostra a quantidade de alunos que concluíram ou não o curso preparatório para os testes. Pode-se concluir que existem 358 alunos que não concluíram o curso preparatório, enquanto 642 que não concluíram.

# %%
# Plotar um gráfico com a nota média em Leitura para cada status do curso preparatório para os testes
df7 = df.groupby('test preparation course')[['writing score']].mean()

# %% [markdown]
# ### ▶ Tabela 7:
#
# ---

# %%
# nota média em Leitura
df7
# Out:
#                          writing score
# test preparation course
# completed                    74.418994
# none                         64.504673

# %% [markdown]
# Já a Tabela 7 acima mostra a média das notas dos alunos em Leitura, relacionando com o status do curso preparatório para os testes: concluído ou não. Pode-se concluir que a média foi maior quando os alunos completaram o curso preparatório.

# %% [markdown]
# ### 📊 Gráfico 3:
#
# ---

# %%
df7.plot(kind = 'bar').set_title('Nota média em Leitura por Status do curso preparatório para os testes')
# Out:
# Text(0.5, 1.0, 'Nota média em Leitura por Status do curso preparatório para os testes')

# %% [markdown]
# O Gráfico 3 mostra a nota média em Leitura por status do curso preparatório para os testes. O eixo y representa a nota média em Leitura e o eixo x representa o Status do curso preparatório para os testes. Os alunos que concluíram o curso preparatório possuem melhores médias em Leitura.
